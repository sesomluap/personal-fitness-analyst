# %%
# Dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pathlib import Path
from scipy.stats import linregress
from requests.structures import CaseInsensitiveDict
import datetime
from scipy import stats
import time

# %%
# File path

filepath = Path('Resources/Unorganized/child_lead.csv')
airpath = Path('Resources/air.csv')

child_lead_df = pd.read_csv(filepath)
air_df = pd.read_csv(airpath)

child_lead_df.head()
air_df.head()
# Out:
#   county     fips    year ozonePersonDayMon ozoneDayStdMon  ozoneDayStdMod  \
# 0  Anoka  27003.0  2000.0            596168              2             NaN
# 1  Anoka  27003.0  2001.0           2418168              8             5.0
# 2  Anoka  27003.0  2002.0           1849026              6             4.0
# 3  Anoka  27003.0  2003.0           1252788              4             3.0
# 4  Anoka  27003.0  2004.0            316830              1             0.0
#
#          ozoneAvgMod  ozoneModelFlag         pm25AvgMon   pm25PersonDayMon  \
# 0  No data available             0.0  No data available  No data available
# 1  No data available             1.0  No data available  No data available
# 2  No data available             1.0  No data available  No data available
# 3  No data available             1.0  No data available  No data available
# 4  No data available             1.0  No data available  No data available
#
#           pm25PctMon         pm25AvgMod  pm25ModelFlag hasMonitor  \
# 0  No data available  No data available            0.0          y
# 1  No data available               12.3            1.0          y
# 2  No data available                 11            1.0          y
# 3  No data available                 12            1.0          y
# 4  No data available               11.5            1.0          y
#
#   hasOzoneMonitor hasPm25Monitor  Unnamed: 16
# 0               y              n          NaN
# 1               y              n          NaN
# 2               y              n          NaN
# 3               y              n          NaN
# 4               y              n          NaN
